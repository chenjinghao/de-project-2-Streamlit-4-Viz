# %%
from connection.database import get_engine
import sqlalchemy
import pandas as pd

# %%
engine = get_engine()

def get_dates(engine):
    query = "SELECT DISTINCT date FROM mart_price_news__analysis ORDER BY date DESC"

    try:
        with engine.connect() as conn:
            # 1. Execute using SQLAlchemy directly
            result = conn.execute(sqlalchemy.text(query))
            
            # 2. Construct DataFrame from the result object
            # result.fetchall() gets the data
            # result.keys() gets the column names
            df = pd.DataFrame(result.fetchall(), columns=result.keys())

            # 3. put value from date column into a list
            date_list = df['date'].tolist()
            
            return date_list
    except Exception as e:
        print(e)

# %%
date_list = get_dates(engine)

# %%
# Most recent date in a list
most_recent_date = max(date_list)
print("Most recent date:", most_recent_date)
# Out:
# Most recent date: 2026-02-05

# %%
def get_stock_info_4_selected_date(engine, selected_date):
    query = f"SELECT * FROM mart_price_news__analysis WHERE date = '{selected_date}' ORDER BY date DESC"

    try:
        with engine.connect() as conn:
            # 1. Execute using SQLAlchemy directly
            result = conn.execute(sqlalchemy.text(query))
            
            # 2. Construct DataFrame from the result object
            # result.fetchall() gets the data
            # result.keys() gets the column names
            df = pd.DataFrame(result.fetchall(), columns=result.keys())
            
            return df
    except Exception as e:
        print(e)

# %%
print(get_stock_info_4_selected_date(engine, most_recent_date))
# Out:
#          date ticker  price      volume change_amount change_percentage  rn  \
# 0  2026-02-05   MOBX  0.231   417069837        0.0481           26.2985   3
# 1  2026-02-05   SOXS  2.235  1061790640         0.265           13.4518   1
# 2  2026-02-05   BYAH    0.1   559222914        0.0213           27.0648   2
#
#   avg_close_price_past_100days max_price_past_100days min_price_past_100days  \
# 0                         0.56                   1.12                   0.17
# 1                         3.53                   6.41                   1.72
# 2                         0.29                   0.55                   0.05
#
#    ... max_volume_past_100days min_volume_past_100days  \
# 0  ...            422710408.00               200468.00
# 1  ...           1073322334.00             78503115.00
# 2  ...            568145060.00                36203.00
#
#            price_vs_100days_avg          volume_vs_100days_avg bullish_count  \
# 0  Below Average 100 Days price  Above Average 100 Days volume          None
# 1  Below Average 100 Days price  Above Average 100 Days volume          None
# 2  Below Average 100 Days price  Above Average 100 Days volume          None
#
#   bearish_count neutral_count somewhat_bullish_count somewhat_bearish_count  \
# 0          None          None                   None                   None
# 1          None          None                   None                   None
# 2          None          None                   None                   None
#
#   avg_sentiment_score
# 0                None
# 1                None
# 2                None
#
# [3 rows x 21 columns]

# %%
def get_biz_info_4_selected_ticker(engine, selected_ticker):
    query = f"SELECT * FROM biz_info_lookup WHERE \"Symbol\" = '{selected_ticker}'"

    try:
        with engine.connect() as conn:
            # 1. Execute using SQLAlchemy directly
            result = conn.execute(sqlalchemy.text(query))
            
            # 2. Construct DataFrame from the result object
            # result.fetchall() gets the data
            # result.keys() gets the column names
            df = pd.DataFrame(result.fetchall(), columns=result.keys())
            
            return df
    except Exception as e:
        print(e)

# %%
get_biz_info_4_selected_ticker(engine, 'NVDA')
# Out:
#   Symbol     AssetType                Name  \
# 0   NVDA  Common Stock  NVIDIA Corporation
#
#                                          Description      CIK Exchange  \
# 0  NVIDIA Corporation is a premier American multi...  1045810   NASDAQ
#
#   Currency Country      Sector        Industry  ... 52WeekHigh 52WeekLow  \
# 0      USD     USA  TECHNOLOGY  SEMICONDUCTORS  ...     212.18      86.6
#
#   50DayMovingAverage 200DayMovingAverage SharesOutstanding  SharesFloat  \
# 0             184.56              164.06       24305000000  23330673000
#
#   PercentInsiders PercentInstitutions DividendDate ExDividendDate
# 0           4.329              69.493   2025-12-26     2025-12-04
#
# [1 rows x 55 columns]
